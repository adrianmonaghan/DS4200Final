# %%
import pandas as pd

# %%
performance_1718 = pd.read_csv('/Users/liuconghan/Desktop/NEU undergraduate/大四/上学期/Foundations of Data science/Final Project/Archive/2017-2018 NBA.csv')

# %%
salary_1819 = pd.read_csv('/Users/liuconghan/Desktop/NEU undergraduate/大四/上学期/Foundations of Data science/Final Project/Archive/2018-2019 Salary.csv')

# %%
performance_1718.head()
# Out:
#    RANK       FULL NAME TEAM POS   AGE  GP   MPG  MIN%  USG%    TOr  ...  RPG  \
# 0     1    Aaron Brooks  Min  PG  33.0  32   5.9  12.3  19.8  0.130  ...  0.5
# 1     2    Aaron Gordon  Orl  SF  22.0  58  32.9  68.6  24.7  0.100  ...  7.9
# 2     3  Aaron Harrison  Dal  SG  23.0   9  25.9  54.0  15.5  0.038  ...  2.7
# 3     4   Aaron Jackson  Hou   F  31.0   1  34.5  71.9  13.9  0.092  ...  3.0
# 4     5     Abdel Nader  Bos  SF  24.0  48  10.9  22.6  17.1  0.170  ...  1.5
#
#    TRB%  APG  AST%   SPG   BPG  TOPG   VI   ORTG   DRTG
# 0   5.2  0.6  15.0  0.19  0.00  0.34  6.0  103.1  100.4
# 1  13.2  2.3  11.7  1.02  0.78  1.84  8.3  103.6  106.2
# 2   5.7  1.2   6.7  1.00  0.22  0.33  4.3   87.9  100.8
# 3   4.9  1.0   4.0  0.00  0.00  1.00  3.3   91.3  101.6
# 4   7.4  0.5   7.2  0.31  0.21  0.71  4.8   83.1   99.1
#
# [5 rows x 29 columns]

# %%
salary_1819.head()
# Out:
#    Unnamed: 0           Name           Salary    Season2
# 0           0  Stephen Curry  $37,457,154.00   2018-2019
# 1           1   LeBron James  $35,654,150.00   2018-2019
# 2           2  Blake Griffin  $32,088,932.00   2018-2019
# 3           3     Kyle Lowry  $31,200,000.00   2018-2019
# 4           4    Mike Conley  $30,521,115.00   2018-2019

# %%
performance_1718.sort_values(by = ['GP'],ascending = False,inplace = True)

# %%
performance_1718.head()
# Out:
#      RANK          FULL NAME TEAM POS   AGE  GP   MPG  MIN%  USG%    TOr  ...  \
# 43     44    Bismack Biyombo  Orl   C  25.0  82  18.2  38.0  14.9  0.166  ...
# 462   463  Patrick Patterson  Okc  PF  28.0  82  15.5  32.3  10.8  0.103  ...
# 26     27     Andrew Wiggins  Min  SF  22.0  82  36.3  75.7  23.4  0.088  ...
# 469   470          PJ Tucker  Hou  SF  32.0  82  27.8  58.0  10.5  0.137  ...
# 388   389      Marcin Gortat  Was   C  33.0  82  25.3  52.7  15.5  0.135  ...
#
#      RPG  TRB%  APG  AST%   SPG   BPG  TOPG   VI   ORTG   DRTG
# 43   5.7  17.2  0.8   6.5  0.26  1.16  1.02  6.5  108.7  101.2
# 462  2.3   8.4  0.7   6.1  0.59  0.28  0.40  4.8  114.2  103.7
# 26   4.4   6.9  2.0   8.2  1.11  0.62  1.68  5.9  101.2  109.5
# 469  5.6  11.3  0.9   4.6  0.94  0.32  0.90  4.5  107.0   99.1
# 388  7.6  17.0  1.8  10.6  0.49  0.74  1.21  7.7  112.1  101.8
#
# [5 rows x 29 columns]

# %%
performance_1718.drop_duplicates(subset=['FULL NAME'], keep='first', inplace = True)

# %%
performance_1718
# Out:
#      RANK            FULL NAME TEAM POS   AGE  GP   MPG  MIN%  USG%    TOr  \
# 43     44      Bismack Biyombo  Orl   C  25.0  82  18.2  38.0  14.9  0.166
# 462   463    Patrick Patterson  Okc  PF  28.0  82  15.5  32.3  10.8  0.103
# 26     27       Andrew Wiggins  Min  SF  22.0  82  36.3  75.7  23.4  0.088
# 469   470            PJ Tucker  Hou  SF  32.0  82  27.8  58.0  10.5  0.137
# 388   389        Marcin Gortat  Was   C  33.0  82  25.3  52.7  15.5  0.135
# ..    ...                  ...  ...  ..   ...  ..   ...   ...   ...    ...
# 569   570          Tyler Lydon  Den  PF  21.0   1   2.2   4.6   0.0    NaN
# 28     29        Anthony Brown  Min  SF  25.0   1   3.7   7.7  12.0  0.000
# 377   378            Luol Deng  Lal  SF  32.0   1  13.1  27.3   9.7  0.333
# 560   561  Trey McKinney-Jones  Ind  SG  27.0   1   1.2   2.5   0.0    NaN
# 79     80        Chris Boucher  Gol  PF  25.0   1   1.3   2.7  33.8  0.000
#
#      ...  RPG  TRB%  APG  AST%   SPG   BPG  TOPG   VI   ORTG   DRTG
# ...

# %%
nba_P_1718_S_1819 = pd.merge(performance_1718, salary_1819, left_on = "FULL NAME", right_on = "Name", how = "inner")

# %%
nba_P_1718_S_1819
# Out:
#      RANK          FULL NAME TEAM POS   AGE  GP   MPG  MIN%  USG%    TOr  ...  \
# 0      44    Bismack Biyombo  Orl   C  25.0  82  18.2  38.0  14.9  0.166  ...
# 1     463  Patrick Patterson  Okc  PF  28.0  82  15.5  32.3  10.8  0.103  ...
# 2      27     Andrew Wiggins  Min  SF  22.0  82  36.3  75.7  23.4  0.088  ...
# 3     389      Marcin Gortat  Was   C  33.0  82  25.3  52.7  15.5  0.135  ...
# 4     481     Raymond Felton  Okc  PG  33.0  82  16.6  34.7  20.3  0.117  ...
# ..    ...                ...  ...  ..   ...  ..   ...   ...   ...    ...  ...
# 404   275         Jeremy Lin  Bro  PG  29.0   1  25.2  52.5  31.1  0.166  ...
# 405   324      Justin Patton  Min   C  20.0   1   3.7   7.7  23.9  0.000  ...
# 406   570        Tyler Lydon  Den  PF  21.0   1   2.2   4.6   0.0    NaN  ...
# 407   378          Luol Deng  Lal  SF  32.0   1  13.1  27.3   9.7  0.333  ...
# 408    80      Chris Boucher  Gol  PF  25.0   1   1.3   2.7  33.8  0.000  ...
#
# ...

# %%
nba_P_1718_S_1819.drop(columns = "RANK", inplace = True)

# %%
nba_P_1718_S_1819.head()
# Out:
#            FULL NAME TEAM POS   AGE  GP   MPG  MIN%  USG%    TOr  FTA  ...  \
# 0    Bismack Biyombo  Orl   C  25.0  82  18.2  38.0  14.9  0.166  157  ...
# 1  Patrick Patterson  Okc  PF  28.0  82  15.5  32.3  10.8  0.103   46  ...
# 2     Andrew Wiggins  Min  SF  22.0  82  36.3  75.7  23.4  0.088  314  ...
# 3      Marcin Gortat  Was   C  33.0  82  25.3  52.7  15.5  0.135  163  ...
# 4     Raymond Felton  Okc  PG  33.0  82  16.6  34.7  20.3  0.117   44  ...
#
#     SPG   BPG  TOPG   VI   ORTG   DRTG  Unnamed: 0               Name  \
# 0  0.26  1.16  1.02  6.5  108.7  101.2          69    Bismack Biyombo
# 1  0.59  0.28  0.40  4.8  114.2  103.7         192  Patrick Patterson
# 2  1.11  0.62  1.68  5.9  101.2  109.5          29     Andrew Wiggins
# 3  0.49  0.74  1.21  7.7  112.1  101.8          81      Marcin Gortat
# 4  0.60  0.20  0.93  7.7  105.4  104.8         362     Raymond Felton
#
#             Salary    Season2
# 0  $17,000,000.00   2018-2019
# 1   $5,451,600.00   2018-2019
# ...

# %%
nba_P_1718_S_1819.drop(columns = "Unnamed: 0", inplace = True)

# %%
nba_P_1718_S_1819.drop(columns = "Name", inplace = True)

# %%
nba_P_1718_S_1819.drop(columns = "Season2", inplace = True)

# %%
nba_P_1718_S_1819.head()
# Out:
#            FULL NAME TEAM POS   AGE  GP   MPG  MIN%  USG%    TOr  FTA  ...  \
# 0    Bismack Biyombo  Orl   C  25.0  82  18.2  38.0  14.9  0.166  157  ...
# 1  Patrick Patterson  Okc  PF  28.0  82  15.5  32.3  10.8  0.103   46  ...
# 2     Andrew Wiggins  Min  SF  22.0  82  36.3  75.7  23.4  0.088  314  ...
# 3      Marcin Gortat  Was   C  33.0  82  25.3  52.7  15.5  0.135  163  ...
# 4     Raymond Felton  Okc  PG  33.0  82  16.6  34.7  20.3  0.117   44  ...
#
#    TRB%  APG  AST%   SPG   BPG  TOPG   VI   ORTG   DRTG           Salary
# 0  17.2  0.8   6.5  0.26  1.16  1.02  6.5  108.7  101.2  $17,000,000.00
# 1   8.4  0.7   6.1  0.59  0.28  0.40  4.8  114.2  103.7   $5,451,600.00
# 2   6.9  2.0   8.2  1.11  0.62  1.68  5.9  101.2  109.5  $25,467,250.00
# 3  17.0  1.8  10.6  0.49  0.74  1.21  7.7  112.1  101.8  $13,565,218.00
# 4   6.4  2.5  22.5  0.60  0.20  0.93  7.7  105.4  104.8   $1,512,601.00
#
# [5 rows x 29 columns]

# %%
nba_P_1718_S_1819.to_csv("nba_P_1718_S_1819.csv")

# %%
performance_1819 = pd.read_csv('/Users/liuconghan/Desktop/NEU undergraduate/大四/上学期/Foundations of Data science/Final Project/Archive/2018-2019 NBA.csv')

# %%
salary_1920 = pd.read_csv('/Users/liuconghan/Desktop/NEU undergraduate/大四/上学期/Foundations of Data science/Final Project/Archive/2019-2020 Salary.csv')

# %%
performance_1819.head()
# Out:
#    RANK     FULL NAME TEAM  POS    AGE  GP   MPG  \
# 0   NaN  Alex Abrines  Okc    G  25.69  31  19.0
# 1   NaN    Quincy Acy  Pho    F  28.51  10  12.3
# 2   NaN  Jaylen Adams  Atl    G  22.93  34  12.6
# 3   NaN  Steven Adams  Okc    C  25.73  80  33.4
# 4   NaN   Bam Adebayo  Mia  C-F  21.73  82  23.3
#
#    MIN%Minutes PercentagePercentage of team minutes used by a player while he was on the floor  \
# 0                                               39.5
# 1                                               25.6
# 2                                               26.2
# 3                                               69.5
# 4                                               48.6
#
#    USG%Usage RateUsage rate, a.k.a., usage percentage is an estimate of the percentage of team plays used by a player while he was on the floor  \
# 0                                               12.2
# 1                                                9.2
# ...

# %%
salary_1920.head()
# Out:
#                     team    salary             player position     season
# 0  Golden State Warriors  40231758      Stephen Curry       PG  2019-2020
# 1  Oklahoma City Thunder  38506482         Chris Paul       PG  2019-2020
# 2        Houston Rockets  38506482  Russell Westbrook       PG  2019-2020
# 3     Washington Wizards  38199000          John Wall       PG  2019-2020
# 4          Brooklyn Nets  38199000       Kevin Durant       SF  2019-2020

# %%
performance_1819.sort_values(by = ['GP'],ascending = False,inplace = True)

# %%
performance_1819.head()
# Out:
#      RANK                 FULL NAME TEAM POS    AGE  GP   MPG  \
# 320   NaN               Cory Joseph  Ind   G  27.64  82  25.2
# 215   NaN   Shai Gilgeous-Alexander  Lac   G  20.75  82  26.5
# 72    NaN             Mikal Bridges  Pho   F  22.61  82  29.5
# 570   NaN                 PJ Tucker  Hou   F  33.93  82  34.2
# 97    NaN  Kentavious Caldwell-Pope  Lal   G  26.14  82  24.8
#
#      MIN%Minutes PercentagePercentage of team minutes used by a player while he was on the floor  \
# 320                                               52.4
# 215                                               55.2
# 72                                                61.4
# 570                                               71.2
# 97                                                51.7
#
#      USG%Usage RateUsage rate, a.k.a., usage percentage is an estimate of the percentage of team plays used by a player while he was on the floor  \
# 320                                               13.7
# ...

# %%
performance_1819.drop_duplicates(subset=['FULL NAME'], keep='first', inplace = True)

# %%
performance_1819
# Out:
#      RANK                 FULL NAME TEAM POS    AGE  GP   MPG  \
# 320   NaN               Cory Joseph  Ind   G  27.64  82  25.2
# 215   NaN   Shai Gilgeous-Alexander  Lac   G  20.75  82  26.5
# 72    NaN             Mikal Bridges  Pho   F  22.61  82  29.5
# 570   NaN                 PJ Tucker  Hou   F  33.93  82  34.2
# 97    NaN  Kentavious Caldwell-Pope  Lal   G  26.14  82  24.8
# ..    ...                       ...  ...  ..    ...  ..   ...
# 525   NaN             Jordan Sibert  Atl   G  26.69   1   4.2
# 364   NaN               Kalin Lucas  Det   G  29.88   1   5.6
# 267   NaN              John Holland  Cle   G  30.43   1   0.7
# 357   NaN               Zach Lofton  Det   G  26.39   1   3.8
# 147   NaN               Tyler Davis  Okc   C  21.89   1   0.9
#
#      MIN%Minutes PercentagePercentage of team minutes used by a player while he was on the floor  \
# 320                                               52.4
# 215                                               55.2
# ...

# %%
nba_P_1819_S_1920 = pd.merge(performance_1819, salary_1920, left_on = "FULL NAME", right_on = "player", how = "inner")

# %%
nba_P_1819_S_1920
# Out:
#      RANK                 FULL NAME TEAM  POS    AGE  GP   MPG  \
# 0     NaN               Cory Joseph  Ind    G  27.64  82  25.2
# 1     NaN   Shai Gilgeous-Alexander  Lac    G  20.75  82  26.5
# 2     NaN             Mikal Bridges  Pho    F  22.61  82  29.5
# 3     NaN  Kentavious Caldwell-Pope  Lal    G  26.14  82  24.8
# 4     NaN           DeAndre' Bembry  Atl    F  24.77  82  23.6
# ..    ...                       ...  ...  ...    ...  ..   ...
# 405   NaN            Gary Payton II  Was    G  26.36   3   5.3
# 406   NaN               Okaro White  Was    F  26.66   3   2.1
# 407   NaN              Ike Anigbogu  Ind    C  20.47   3   2.1
# 408   NaN               Yante Maten  Mia    F  22.66   2   6.5
# 409   NaN                   Zhou Qi  Hou  F-C  23.23   1   1.0
#
#      MIN%Minutes PercentagePercentage of team minutes used by a player while he was on the floor  \
# 0                                                 52.4
# ...

# %%
nba_P_1819_S_1920.drop(columns = "RANK", inplace = True)

# %%
nba_P_1819_S_1920.drop(columns = "team", inplace = True)

# %%
nba_P_1819_S_1920.drop(columns = "player", inplace = True)

# %%
nba_P_1819_S_1920.drop(columns = "position", inplace = True)

# %%
nba_P_1819_S_1920.drop(columns = "season", inplace = True)

# %%
nba_P_1819_S_1920
# Out:
#                     FULL NAME TEAM  POS    AGE  GP   MPG  \
# 0                 Cory Joseph  Ind    G  27.64  82  25.2
# 1     Shai Gilgeous-Alexander  Lac    G  20.75  82  26.5
# 2               Mikal Bridges  Pho    F  22.61  82  29.5
# 3    Kentavious Caldwell-Pope  Lal    G  26.14  82  24.8
# 4             DeAndre' Bembry  Atl    F  24.77  82  23.6
# ..                        ...  ...  ...    ...  ..   ...
# 405            Gary Payton II  Was    G  26.36   3   5.3
# 406               Okaro White  Was    F  26.66   3   2.1
# 407              Ike Anigbogu  Ind    C  20.47   3   2.1
# 408               Yante Maten  Mia    F  22.66   2   6.5
# 409                   Zhou Qi  Hou  F-C  23.23   1   1.0
#
#      MIN%Minutes PercentagePercentage of team minutes used by a player while he was on the floor  \
# 0                                                 52.4
# 1                                                 55.2
# 2                                                 61.4
# ...

# %%
nba_P_1819_S_1920.to_csv("nba_P_1819_S_1920.csv")

# %%
performance_1920 = pd.read_csv('/Users/liuconghan/Desktop/NEU undergraduate/大四/上学期/Foundations of Data science/Final Project/Archive/2019-2020 NBA.csv')

# %%
salary_2021 = pd.read_csv('/Users/liuconghan/Desktop/NEU undergraduate/大四/上学期/Foundations of Data science/Final Project/Archive/2020-2021 Salary.csv')

# %%
salary_2021.head()
# Out:
#    Unnamed: 0               Name           Salary    Season2
# 0           0      Stephen Curry  $40,231,758.00   2020-2021
# 1           1  Russell Westbrook  $38,506,482.00   2020-2021
# 2           2       Kevin Durant  $38,199,000.00   2020-2021
# 3           3       LeBron James  $37,436,858.00   2020-2021
# 4           4      Blake Griffin  $34,449,964.00   2020-2021

# %%
performance_1920.sort_values(by = ['GP'],ascending = False,inplace = True)

# %%
performance_1920.head()
# Out:
#      RANK        FULL NAME TEAM  POS    AGE  GP   MPG  \
# 311   NaN      Maxi Kleber  Dal    F  28.54  74  25.5
# 396   NaN     Monte Morris  Den    G  25.13  73  22.4
# 257   NaN   Justin Holiday  Ind  F-G  31.36  73  25.0
# 583   NaN     Delon Wright  Dal    G  28.30  73  21.5
# 472   NaN  Duncan Robinson  Mia    F  26.32  73  29.7
#
#      MIN%Minutes PercentagePercentage of team minutes used by a player while he was on the floor  \
# 311                                               53.2
# 396                                               46.7
# 257                                               52.1
# 583                                               44.8
# 472                                               61.8
#
#      USG%Usage RateUsage rate, a.k.a., usage percentage is an estimate of the percentage of team plays used by a player while he was on the floor  \
# 311                                               13.9
# 396                                               17.5
# ...

# %%
performance_1920.drop_duplicates(subset=['FULL NAME'], keep='first', inplace = True)

# %%
performance_1920
# Out:
#      RANK        FULL NAME TEAM  POS    AGE  GP   MPG  \
# 311   NaN      Maxi Kleber  Dal    F  28.54  74  25.5
# 396   NaN     Monte Morris  Den    G  25.13  73  22.4
# 257   NaN   Justin Holiday  Ind  F-G  31.36  73  25.0
# 583   NaN     Delon Wright  Dal    G  28.30  73  21.5
# 472   NaN  Duncan Robinson  Mia    F  26.32  73  29.7
# ..    ...              ...  ...  ...    ...  ..   ...
# 410   NaN     Malik Newman  Cle    G  23.48   1   3.7
# 93    NaN   Devontae Cacok  Lal    F  23.85   1   8.9
# 58    NaN   Marques Bolden  Cle    C  22.33   1   2.8
# 134   NaN   Jamal Crawford  Bro    G  40.40   1   6.0
# 346   NaN      J.P. Macura  Cle    G  25.20   1   0.6
#
#      MIN%Minutes PercentagePercentage of team minutes used by a player while he was on the floor  \
# 311                                               53.2
# 396                                               46.7
# 257                                               52.1
# ...

# %%
nba_P_1920_S_2021 = pd.merge(performance_1920, salary_2021, left_on = "FULL NAME", right_on = "Name", how = "inner")

# %%
nba_P_1920_S_2021
# Out:
#      RANK        FULL NAME TEAM  POS    AGE  GP   MPG  \
# 0     NaN      Maxi Kleber  Dal    F  28.54  74  25.5
# 1     NaN     Monte Morris  Den    G  25.13  73  22.4
# 2     NaN   Justin Holiday  Ind  F-G  31.36  73  25.0
# 3     NaN     Delon Wright  Dal    G  28.30  73  21.5
# 4     NaN  Duncan Robinson  Mia    F  26.32  73  29.7
# ..    ...              ...  ...  ...    ...  ..   ...
# 444   NaN     Luka Samanic  San    F  20.60   3  16.1
# 445   NaN      Isaiah Roby  Okc    F  22.53   3   3.8
# 446   NaN     Tyler Zeller  San  F-C  30.58   2   2.0
# 447   NaN        Max Strus  Chi  G-F  24.38   2   3.1
# 448   NaN    Ryan Anderson  Hou    F  32.27   2   7.0
#
#      MIN%Minutes PercentagePercentage of team minutes used by a player while he was on the floor  \
# 0                                                 53.2
# 1                                                 46.7
# 2                                                 52.1
# ...

# %%
nba_P_1920_S_2021.drop(columns = "RANK", inplace = True)

# %%
nba_P_1920_S_2021.drop(columns = "Unnamed: 0", inplace = True)

# %%
nba_P_1920_S_2021.drop(columns = "Name", inplace = True)

# %%
nba_P_1920_S_2021.drop(columns = "Season2", inplace = True)

# %%
nba_P_1920_S_2021
# Out:
#            FULL NAME TEAM  POS    AGE  GP   MPG  \
# 0        Maxi Kleber  Dal    F  28.54  74  25.5
# 1       Monte Morris  Den    G  25.13  73  22.4
# 2     Justin Holiday  Ind  F-G  31.36  73  25.0
# 3       Delon Wright  Dal    G  28.30  73  21.5
# 4    Duncan Robinson  Mia    F  26.32  73  29.7
# ..               ...  ...  ...    ...  ..   ...
# 444     Luka Samanic  San    F  20.60   3  16.1
# 445      Isaiah Roby  Okc    F  22.53   3   3.8
# 446     Tyler Zeller  San  F-C  30.58   2   2.0
# 447        Max Strus  Chi  G-F  24.38   2   3.1
# 448    Ryan Anderson  Hou    F  32.27   2   7.0
#
#      MIN%Minutes PercentagePercentage of team minutes used by a player while he was on the floor  \
# 0                                                 53.2
# 1                                                 46.7
# 2                                                 52.1
# 3                                                 44.8
# 4                                                 61.8
# ...

# %%
nba_P_1920_S_2021.to_csv("nba_P_1920_S_2021.csv")

# %%
dic = {"MIN%Minutes PercentagePercentage of team minutes used by a player while he was on the floor":"MIN%",
       "USG%Usage RateUsage rate, a.k.a., usage percentage is an estimate of the percentage of team plays used by a player while he was on the floor":"USG%",
      "Tor%Turnover RateA metric that estimates the number of turnovers a player commits per 100 possessions":"TOr",
      "FTA":"FTA", "FT%":"FT%","2PA":"2PA","2P%":"2P%","3PA":"3PA","3P%":"3P%",
      "eFG%Effective Shooting PercentageWith eFG%, three-point shots made are worth 50% more than two-point shots made. eFG% Formula=(FGM+ (0.5 x 3PM))/FGA":"eFG%",
      "TS%True Shooting PercentageTrue shooting percentage is a measure of shooting efficiency that takes into account field goals, 3-point field goals, and free throws.":"TS%",
      "PPGPointsPoints per game.":"PPG","RPGReboundsRebounds per game.":"RPG",
      "TRB%Total Rebound PercentageTotal rebound percentage is estimated percentage of available rebounds grabbed by the player while the player is on the court.":"TRB%",
      'APGAssistsAssists per game.':'APG',
      'AST%Assist PercentageAssist percentage is an estimated percentage of teammate field goals a player assisted while the player is on the court':'AST%',
      'SPGStealsSteals per game.':'SPG', 'BPGBlocksBlocks per game.':'BPG','TOPGTurnoversTurnovers per game.':'TOPG',
      'VIVersatility IndexVersatility index is a metric that measures a player’s ability to produce in points, assists, and rebounds. The average player will score around a five on the index, while top players score above 10':'VI',
      'ORTGOffensive RatingIndividual offensive rating is the number of points produced by a player per 100 total individual possessions.':'ORTG',
      'DRTGDefensive RatingIndividual defensive rating estimates how many points the player allowed per 100 possessions he individually faced while staying on the court.':'DRTG',
      "salary":"Salary"}

# %%
nba_P_1819_S_1920.rename(columns= dic,inplace = True)

# %%
nba_P_S_total = nba_P_1718_S_1819.append(nba_P_1819_S_1920,ignore_index=True)

# %%
nba_P_S_total
# Out:
#              FULL NAME TEAM  POS    AGE  GP   MPG  MIN%  USG%     TOr  FTA  \
# 0      Bismack Biyombo  Orl    C  25.00  82  18.2  38.0  14.9   0.166  157
# 1    Patrick Patterson  Okc   PF  28.00  82  15.5  32.3  10.8   0.103   46
# 2       Andrew Wiggins  Min   SF  22.00  82  36.3  75.7  23.4   0.088  314
# 3        Marcin Gortat  Was    C  33.00  82  25.3  52.7  15.5   0.135  163
# 4       Raymond Felton  Okc   PG  33.00  82  16.6  34.7  20.3   0.117   44
# ..                 ...  ...  ...    ...  ..   ...   ...   ...     ...  ...
# 814     Gary Payton II  Was    G  26.36   3   5.3  11.0  24.0  11.100    0
# 815        Okaro White  Was    F  26.66   3   2.1   4.4  13.5   0.000    0
# 816       Ike Anigbogu  Ind    C  20.47   3   2.1   4.3  28.2  25.000    0
# 817        Yante Maten  Mia    F  22.66   2   6.5  13.5  13.2   0.000    0
# 818            Zhou Qi  Hou  F-C  23.23   1   1.0   2.1  43.4   0.000    0
#
#      ...  TRB%  APG  AST%   SPG   BPG  TOPG    VI   ORTG   DRTG  \
# ...

# %%
dic1 = {"MIN%Minutes PercentagePercentage of team minutes used by a player while he was on the floor":"MIN%",
       "USG%Usage RateUsage rate, a.k.a., usage percentage is an estimate of the percentage of team plays used by a player while he was on the floor":"USG%",
      "TO%Turnover RateA metric that estimates the number of turnovers a player commits per 100 possessions":"TOr",
      "FTA":"FTA", "FT%":"FT%","2PA":"2PA","2P%":"2P%","3PA":"3PA","3P%":"3P%",
      "eFG%Effective Shooting PercentageWith eFG%, three-point shots made are worth 50% more than two-point shots made. eFG% Formula=(FGM+ (0.5 x 3PM))/FGA":"eFG%",
      "TS%True Shooting PercentageTrue shooting percentage is a measure of shooting efficiency that takes into account field goals, 3-point field goals, and free throws.":"TS%",
      "PPGPointsPoints per game.":"PPG","RPGReboundsRebounds per game.":"RPG",
      "TRB%Total Rebound PercentageTotal rebound percentage is estimated percentage of available rebounds grabbed by the player while the player is on the court.":"TRB%",
      'APGAssistsAssists per game.':'APG',
      'AST%Assist PercentageAssist percentage is an estimated percentage of teammate field goals a player assisted while the player is on the court':'AST%',
      'SPGStealsSteals per game.':'SPG', 'BPGBlocksBlocks per game.':'BPG','TOPGTurnoversTurnovers per game.':'TOPG',
      'VIVersatility IndexVersatility index is a metric that measures a player’s ability to produce in points, assists, and rebounds. The average player will score around a five on the index, while top players score above 10':'VI',
      'ORTGOffensive RatingIndividual offensive rating is the number of points produced by a player per 100 total individual possessions.':'ORTG',
      'DRTGDefensive RatingIndividual defensive rating estimates how many points the player allowed per 100 possessions he individually faced while staying on the court.':'DRTG',
      "Salary":"Salary"}

# %%
nba_P_1920_S_2021.rename(columns= dic1,inplace = True)

# %%
nba_P_S_total = nba_P_S_total.append(nba_P_1920_S_2021,ignore_index=True)

# %%
nba_P_S_total
# Out:
#               FULL NAME TEAM  POS    AGE  GP   MPG  MIN%  USG%     TOr  FTA  \
# 0       Bismack Biyombo  Orl    C  25.00  82  18.2  38.0  14.9   0.166  157
# 1     Patrick Patterson  Okc   PF  28.00  82  15.5  32.3  10.8   0.103   46
# 2        Andrew Wiggins  Min   SF  22.00  82  36.3  75.7  23.4   0.088  314
# 3         Marcin Gortat  Was    C  33.00  82  25.3  52.7  15.5   0.135  163
# 4        Raymond Felton  Okc   PG  33.00  82  16.6  34.7  20.3   0.117   44
# ...                 ...  ...  ...    ...  ..   ...   ...   ...     ...  ...
# 1263       Luka Samanic  San    F  20.60   3  16.1  33.6  17.6  10.100    4
# 1264        Isaiah Roby  Okc    F  22.53   3   3.8   7.9   7.7  50.000    0
# 1265       Tyler Zeller  San  F-C  30.58   2   2.0   4.1  44.3   0.000    0
# 1266          Max Strus  Chi  G-F  24.38   2   3.1   6.5  23.6   0.000    1
# 1267      Ryan Anderson  Hou    F  32.27   2   7.0  14.6  23.7  12.500    0
#
# ...

# %%
nba_P_S_total.drop(columns = 'FULL NAME', inplace = True)

# %%
nba_P_S_total
# Out:
#      TEAM  POS    AGE  GP   MPG  MIN%  USG%     TOr  FTA    FT%  ...  TRB%  \
# 0     Orl    C  25.00  82  18.2  38.0  14.9   0.166  157  0.650  ...  17.2
# 1     Okc   PF  28.00  82  15.5  32.3  10.8   0.103   46  0.870  ...   8.4
# 2     Min   SF  22.00  82  36.3  75.7  23.4   0.088  314  0.643  ...   6.9
# 3     Was    C  33.00  82  25.3  52.7  15.5   0.135  163  0.675  ...  17.0
# 4     Okc   PG  33.00  82  16.6  34.7  20.3   0.117   44  0.818  ...   6.4
# ...   ...  ...    ...  ..   ...   ...   ...     ...  ...    ...  ...   ...
# 1263  San    F  20.60   3  16.1  33.6  17.6  10.100    4  0.750  ...  11.1
# 1264  Okc    F  22.53   3   3.8   7.9   7.7  50.000    0  0.000  ...   9.7
# 1265  San  F-C  30.58   2   2.0   4.1  44.3   0.000    0  0.000  ...  55.3
# 1266  Chi  G-F  24.38   2   3.1   6.5  23.6   0.000    1  1.000  ...   8.9
# 1267  Hou    F  32.27   2   7.0  14.6  23.7  12.500    0  0.000  ...  26.2
#
# ...

# %%
nba_P_S_total.to_csv("nba_P_S_total.csv")
